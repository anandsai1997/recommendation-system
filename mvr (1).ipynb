# %%
import pandas as pd
import numpy as np
import pickle

# %%
ratings = pd.read_csv("ratings12.csv", encoding='"ISO-8859-1"')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       3        1     4.0   944919407
# 1       6        1     5.0   858275452
# 2       8        1     4.0   833981871
# 3      10        1     4.0   943497887
# 4      11        1     4.5  1230858821

# %%
# split the ratings into training and test
ratings_training = ratings.sample(frac=0.7)
ratings_test = ratings.drop(ratings_training.index)

# %%
# calculate adjusted ratings based on training data
rating_mean= ratings_training.groupby(['movieId'], as_index = False, sort = False).mean().rename(columns = {'rating': 'rating_mean'})[['movieId','rating_mean']]
adjusted_ratings = pd.merge(ratings_training,rating_mean,on = 'movieId', how = 'left', sort = False)
adjusted_ratings['rating_adjusted']=adjusted_ratings['rating']-adjusted_ratings['rating_mean']
# replace 0 adjusted rating values to 1*e-8 in order to avoid 0 denominator
adjusted_ratings.loc[adjusted_ratings['rating_adjusted'] == 0, 'rating_adjusted'] = 1e-8

# %%
# function of building the item-to-item weight matrix
def build_w_matrix(adjusted_ratings, load_existing_w_matrix):
   # define weight matrix
   w_matrix_columns = ['movie_1', 'movie_2', 'weight']
   w_matrix=pd.DataFrame(columns=w_matrix_columns)

   # load weight matrix from pickle file
   if load_existing_w_matrix:
       with open(DEFAULT_PARTICLE_PATH, 'rb') as input:
           w_matrix = pickle.load(input)
       input.close()

   # calculate the similarity values
   else:
       distinct_movies = np.unique(adjusted_ratings['movieId'])

       i = 0
       # for each movie_1 in all movies
       for movie_1 in distinct_movies:

           if i%10==0:
               print(i , "out of ", len(distinct_movies))

           # extract all users who rated movie_1
           user_data = adjusted_ratings[adjusted_ratings['movieId'] == movie_1]
           distinct_users = np.unique(user_data['userId'])

           # record the ratings for users who rated both movie_1 and movie_2
           record_row_columns = ['userId', 'movie_1', 'movie_2', 'rating_adjusted_1', 'rating_adjusted_2']
           record_movie_1_2 = pd.DataFrame(columns=record_row_columns)
           # for each customer C who rated movie_1
           for c_userid in distinct_users:
               print('build weight matrix for customer %d, movie_1 %d' % (c_userid, movie_1))
               # the customer's rating for movie_1
               c_movie_1_rating = user_data[user_data['userId'] == c_userid]['rating_adjusted'].iloc[0]
               # extract movies rated by the customer excluding movie_1
               c_user_data = adjusted_ratings[(adjusted_ratings['userId'] == c_userid) & (adjusted_ratings['movieId'] != movie_1)]
               c_distinct_movies = np.unique(c_user_data['movieId'])

               # for each movie rated by customer C as movie=2
               for movie_2 in c_distinct_movies:
                   # the customer's rating for movie_2
                   c_movie_2_rating = c_user_data[c_user_data['movieId'] == movie_2]['rating_adjusted'].iloc[0]
                   record_row = pd.Series([c_userid, movie_1, movie_2, c_movie_1_rating, c_movie_2_rating], index=record_row_columns)
                   record_movie_1_2 = record_movie_1_2.append(record_row, ignore_index=True)

           # calculate the similarity values between movie_1 and the above recorded movies
           distinct_movie_2 = np.unique(record_movie_1_2['movie_2'])
           # for each movie 2
           for movie_2 in distinct_movie_2:
               print('calculate weight movie_1 %d, movie_2 %d' % (movie_1, movie_2))
               paired_movie_1_2 = record_movie_1_2[record_movie_1_2['movie_2'] == movie_2]
               sim_value_numerator = (paired_movie_1_2['rating_adjusted_1'] * paired_movie_1_2['rating_adjusted_2']).sum()
               sim_value_denominator = np.sqrt(np.square(paired_movie_1_2['rating_adjusted_1']).sum()) * np.sqrt(np.square(paired_movie_1_2['rating_adjusted_2']).sum())
               sim_value_denominator = sim_value_denominator if sim_value_denominator != 0 else 1e-8
               sim_value = sim_value_numerator / sim_value_denominator
               w_matrix = w_matrix.append(pd.Series([movie_1, movie_2, sim_value], index=w_matrix_columns), ignore_index=True)

           i = i + 1

       # output weight matrix to pickle file
       with open(DEFAULT_PARTICLE_PATH, 'wb') as output:
           pickle.dump(w_matrix, output, pickle.HIGHEST_PROTOCOL)
       output.close()

   return w_matrix

# %%
# calculate the predicted ratings
def predict(userId, movieId, w_matrix, adjusted_ratings, rating_mean):
   # fix missing mean rating which was caused by no ratings for the given movie
   
    # mean_rating exists for movieId
   if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
       mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
   else:
       mean_rating = 2.5

   # calculate the rating of the given movie by the given user
   user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
   user_distinct_movies = np.unique(user_other_ratings['movieId'])
   sum_weighted_other_ratings = 0
   sum_weghts = 0
   for movie_j in user_distinct_movies:
       if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
           rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
       else:
           rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
       w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
       if w_movie_1_2.shape[0] > 0:
           user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
           sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
           sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])

   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
   if sum_weghts == 0:
       predicted_rating = mean_rating
   # sum_weights is bigger than 0
   else:
       predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts

   return predicted_rating

# %%
weight_matrix=build_w_matrix(adjusted_ratings, 0)
# Out:
# 0 out of  50
# build weight matrix for customer 3, movie_1 1
# build weight matrix for customer 6, movie_1 1
# build weight matrix for customer 10, movie_1 1
# build weight matrix for customer 11, movie_1 1
# build weight matrix for customer 12, movie_1 1
# build weight matrix for customer 13, movie_1 1
# build weight matrix for customer 14, movie_1 1
# build weight matrix for customer 16, movie_1 1
# build weight matrix for customer 19, movie_1 1
# build weight matrix for customer 22, movie_1 1
# build weight matrix for customer 23, movie_1 1
# build weight matrix for customer 24, movie_1 1
# build weight matrix for customer 34, movie_1 1
# build weight matrix for customer 39, movie_1 1
# build weight matrix for customer 47, movie_1 1
# build weight matrix for customer 53, movie_1 1
# build weight matrix for customer 54, movie_1 1
# build weight matrix for customer 58, movie_1 1
# build weight matrix for customer 59, movie_1 1
# build weight matrix for customer 66, movie_1 1
# build weight matrix for customer 69, movie_1 1
# build weight matrix for customer 80, movie_1 1
# build weight matrix for customer 90, movie_1 1
# build weight matrix for customer 93, movie_1 1
# build weight matrix for customer 96, movie_1 1
# build weight matrix for customer 97, movie_1 1
# build weight matrix for customer 99, movie_1 1
# build weight matrix for customer 105, movie_1 1
# build weight matrix for customer 107, movie_1 1
# build weight matrix for customer 114, movie_1 1
# build weight matrix for customer 115, movie_1 1
# build weight matrix for customer 124, movie_1 1
# build weight matrix for customer 129, movie_1 1
# build weight matrix for customer 131, movie_1 1
# build weight matrix for customer 133, movie_1 1
# build weight matrix for customer 135, movie_1 1
# build weight matrix for customer 136, movie_1 1
# build weight matrix for customer 146, movie_1 1
# build weight matrix for customer 147, movie_1 1
# build weight matrix for customer 155, movie_1 1
# build weight matrix for customer 159, movie_1 1
# build weight matrix for customer 160, movie_1 1
# build weight matrix for customer 162, movie_1 1
# build weight matrix for customer 168, movie_1 1
# build weight matrix for customer 172, movie_1 1
# build weight matrix for customer 175, movie_1 1
# build weight matrix for customer 186, movie_1 1
# build weight matrix for customer 188, movie_1 1
# build weight matrix for customer 199, movie_1 1
# build weight matrix for customer 202, movie_1 1
# build weight matrix for customer 205, movie_1 1
# build weight matrix for customer 208, movie_1 1
# build weight matrix for customer 209, movie_1 1
# build weight matrix for customer 215, movie_1 1
# build weight matrix for customer 216, movie_1 1
# build weight matrix for customer 220, movie_1 1
# build weight matrix for customer 232, movie_1 1
# build weight matrix for customer 233, movie_1 1
# build weight matrix for customer 235, movie_1 1
# build weight matrix for customer 237, movie_1 1
# build weight matrix for customer 238, movie_1 1
# build weight matrix for customer 251, movie_1 1
# build weight matrix for customer 258, movie_1 1
# build weight matrix for customer 260, movie_1 1
# build weight matrix for customer 264, movie_1 1
# build weight matrix for customer 267, movie_1 1
# build weight matrix for customer 269, movie_1 1
# build weight matrix for customer 274, movie_1 1
# build weight matrix for customer 279, movie_1 1
# build weight matrix for customer 285, movie_1 1
# build weight matrix for customer 286, movie_1 1
# build weight matrix for customer 289, movie_1 1
# build weight matrix for customer 294, movie_1 1
# build weight matrix for customer 295, movie_1 1
# build weight matrix for customer 296, movie_1 1
# build weight matrix for customer 305, movie_1 1
# build weight matrix for customer 309, movie_1 1
# build weight matrix for customer 313, movie_1 1
# build weight matrix for customer 314, movie_1 1
# build weight matrix for customer 324, movie_1 1
# build weight matrix for customer 325, movie_1 1
# build weight matrix for customer 329, movie_1 1
# build weight matrix for customer 336, movie_1 1
# build weight matrix for customer 347, movie_1 1
# build weight matrix for customer 354, movie_1 1
# build weight matrix for customer 359, movie_1 1
# build weight matrix for customer 360, movie_1 1
# build weight matrix for customer 370, movie_1 1
# build weight matrix for customer 372, movie_1 1
# build weight matrix for customer 388, movie_1 1
# build weight matrix for customer 389, movie_1 1
# build weight matrix for customer 398, movie_1 1
# build weight matrix for customer 399, movie_1 1
# build weight matrix for customer 401, movie_1 1
# build weight matrix for customer 409, movie_1 1
# build weight matrix for customer 413, movie_1 1
# build weight matrix for customer 419, movie_1 1
# build weight matrix for customer 425, movie_1 1
# build weight matrix for customer 427, movie_1 1
# build weight matrix for customer 432, movie_1 1
# build weight matrix for customer 440, movie_1 1
# build weight matrix for customer 443, movie_1 1
# build weight matrix for customer 453, movie_1 1
# build weight matrix for customer 461, movie_1 1
# build weight matrix for customer 462, movie_1 1
# build weight matrix for customer 466, movie_1 1
# build weight matrix for customer 471, movie_1 1
# build weight matrix for customer 474, movie_1 1
# build weight matrix for customer 479, movie_1 1
# build weight matrix for customer 483, movie_1 1
# build weight matrix for customer 485, movie_1 1
# build weight matrix for customer 488, movie_1 1
# build weight matrix for customer 490, movie_1 1
# build weight matrix for customer 496, movie_1 1
# build weight matrix for customer 505, movie_1 1
# build weight matrix for customer 508, movie_1 1
# build weight matrix for customer 514, movie_1 1
# build weight matrix for customer 516, movie_1 1
# build weight matrix for customer 521, movie_1 1
# build weight matrix for customer 524, movie_1 1
# build weight matrix for customer 531, movie_1 1
# build weight matrix for customer 539, movie_1 1
# build weight matrix for customer 543, movie_1 1
# build weight matrix for customer 546, movie_1 1
# build weight matrix for customer 548, movie_1 1
# build weight matrix for customer 550, movie_1 1
# build weight matrix for customer 552, movie_1 1
# build weight matrix for customer 564, movie_1 1
# build weight matrix for customer 570, movie_1 1
# build weight matrix for customer 571, movie_1 1
# build weight matrix for customer 585, movie_1 1
# build weight matrix for customer 588, movie_1 1
# build weight matrix for customer 589, movie_1 1
# build weight matrix for customer 590, movie_1 1
# build weight matrix for customer 591, movie_1 1
# build weight matrix for customer 592, movie_1 1
# build weight matrix for customer 593, movie_1 1
# build weight matrix for customer 600, movie_1 1
# build weight matrix for customer 603, movie_1 1
# build weight matrix for customer 604, movie_1 1
# build weight matrix for customer 607, movie_1 1
# build weight matrix for customer 611, movie_1 1
# build weight matrix for customer 616, movie_1 1
# build weight matrix for customer 624, movie_1 1
# build weight matrix for customer 627, movie_1 1
# build weight matrix for customer 635, movie_1 1
# build weight matrix for customer 637, movie_1 1
# build weight matrix for customer 642, movie_1 1
# build weight matrix for customer 643, movie_1 1
# build weight matrix for customer 649, movie_1 1
# build weight matrix for customer 651, movie_1 1
# build weight matrix for customer 652, movie_1 1
# build weight matrix for customer 656, movie_1 1
# build weight matrix for customer 659, movie_1 1
# build weight matrix for customer 664, movie_1 1
# build weight matrix for customer 666, movie_1 1
# build weight matrix for customer 673, movie_1 1
# build weight matrix for customer 681, movie_1 1
# build weight matrix for customer 683, movie_1 1
# build weight matrix for customer 685, movie_1 1
# build weight matrix for customer 686, movie_1 1
# build weight matrix for customer 689, movie_1 1
# build weight matrix for customer 694, movie_1 1
# build weight matrix for customer 699, movie_1 1
# build weight matrix for customer 700, movie_1 1
# build weight matrix for customer 708, movie_1 1
# build weight matrix for customer 710, movie_1 1
# build weight matrix for customer 711, movie_1 1
# build weight matrix for customer 712, movie_1 1
# build weight matrix for customer 714, movie_1 1
# build weight matrix for customer 717, movie_1 1
# build weight matrix for customer 724, movie_1 1
# build weight matrix for customer 725, movie_1 1
# build weight matrix for customer 728, movie_1 1
# build weight matrix for customer 733, movie_1 1
# build weight matrix for customer 735, movie_1 1
# build weight matrix for customer 737, movie_1 1
# build weight matrix for customer 738, movie_1 1
# build weight matrix for customer 741, movie_1 1
# build weight matrix for customer 744, movie_1 1
# build weight matrix for customer 755, movie_1 1
# build weight matrix for customer 757, movie_1 1
# build weight matrix for customer 758, movie_1 1
# build weight matrix for customer 761, movie_1 1
# build weight matrix for customer 763, movie_1 1
# build weight matrix for customer 766, movie_1 1
# build weight matrix for customer 769, movie_1 1
# build weight matrix for customer 772, movie_1 1
# build weight matrix for customer 773, movie_1 1
# build weight matrix for customer 774, movie_1 1
# build weight matrix for customer 778, movie_1 1
# build weight matrix for customer 783, movie_1 1
# build weight matrix for customer 785, movie_1 1
# build weight matrix for customer 787, movie_1 1
# build weight matrix for customer 789, movie_1 1
# build weight matrix for customer 792, movie_1 1
# build weight matrix for customer 797, movie_1 1
# build weight matrix for customer 805, movie_1 1
# build weight matrix for customer 809, movie_1 1
# build weight matrix for customer 812, movie_1 1
# build weight matrix for customer 818, movie_1 1
# build weight matrix for customer 822, movie_1 1
# build weight matrix for customer 824, movie_1 1
# build weight matrix for customer 827, movie_1 1
# build weight matrix for customer 829, movie_1 1
# build weight matrix for customer 838, movie_1 1
# build weight matrix for customer 839, movie_1 1
# build weight matrix for customer 850, movie_1 1
# build weight matrix for customer 853, movie_1 1
# build weight matrix for customer 858, movie_1 1
# build weight matrix for customer 868, movie_1 1
# build weight matrix for customer 870, movie_1 1
# build weight matrix for customer 872, movie_1 1
# build weight matrix for customer 873, movie_1 1
# build weight matrix for customer 885, movie_1 1
# build weight matrix for customer 890, movie_1 1
# build weight matrix for customer 898, movie_1 1
# build weight matrix for customer 900, movie_1 1
# build weight matrix for customer 902, movie_1 1
# build weight matrix for customer 910, movie_1 1
# build weight matrix for customer 926, movie_1 1
# build weight matrix for customer 929, movie_1 1
# build weight matrix for customer 935, movie_1 1
# build weight matrix for customer 936, movie_1 1
# build weight matrix for customer 947, movie_1 1
# build weight matrix for customer 949, movie_1 1
# build weight matrix for customer 952, movie_1 1
# build weight matrix for customer 955, movie_1 1
# build weight matrix for customer 964, movie_1 1
# build weight matrix for customer 970, movie_1 1
# build weight matrix for customer 986, movie_1 1
# build weight matrix for customer 987, movie_1 1
# build weight matrix for customer 989, movie_1 1
# build weight matrix for customer 1001, movie_1 1
# build weight matrix for customer 1007, movie_1 1
# build weight matrix for customer 1008, movie_1 1
# build weight matrix for customer 1011, movie_1 1
# build weight matrix for customer 1013, movie_1 1
# build weight matrix for customer 1019, movie_1 1
# build weight matrix for customer 1022, movie_1 1
# build weight matrix for customer 1023, movie_1 1
# build weight matrix for customer 1026, movie_1 1
# build weight matrix for customer 1028, movie_1 1
# build weight matrix for customer 1030, movie_1 1
# build weight matrix for customer 1035, movie_1 1
# build weight matrix for customer 1039, movie_1 1
# build weight matrix for customer 1044, movie_1 1
# build weight matrix for customer 1048, movie_1 1
# build weight matrix for customer 1049, movie_1 1
# build weight matrix for customer 1050, movie_1 1
# build weight matrix for customer 1051, movie_1 1
# build weight matrix for customer 1057, movie_1 1
# build weight matrix for customer 1058, movie_1 1
# build weight matrix for customer 1059, movie_1 1
# build weight matrix for customer 1073, movie_1 1
# build weight matrix for customer 1081, movie_1 1
# build weight matrix for customer 1084, movie_1 1
# build weight matrix for customer 1085, movie_1 1
# build weight matrix for customer 1087, movie_1 1
# build weight matrix for customer 1099, movie_1 1
# build weight matrix for customer 1102, movie_1 1
# build weight matrix for customer 1107, movie_1 1
# build weight matrix for customer 1108, movie_1 1
# build weight matrix for customer 1110, movie_1 1
# build weight matrix for customer 1116, movie_1 1
# build weight matrix for customer 1119, movie_1 1
# build weight matrix for customer 1136, movie_1 1
# build weight matrix for customer 1139, movie_1 1
# build weight matrix for customer 1140, movie_1 1
# build weight matrix for customer 1141, movie_1 1
# build weight matrix for customer 1143, movie_1 1
# build weight matrix for customer 1144, movie_1 1
# build weight matrix for customer 1159, movie_1 1
# build weight matrix for customer 1163, movie_1 1
# build weight matrix for customer 1170, movie_1 1
# build weight matrix for customer 1178, movie_1 1
# build weight matrix for customer 1179, movie_1 1
# build weight matrix for customer 1185, movie_1 1
# build weight matrix for customer 1190, movie_1 1
# build weight matrix for customer 1195, movie_1 1
# build weight matrix for customer 1197, movie_1 1
# build weight matrix for customer 1198, movie_1 1
# build weight matrix for customer 1200, movie_1 1
# build weight matrix for customer 1206, movie_1 1
# build weight matrix for customer 1210, movie_1 1
# build weight matrix for customer 1216, movie_1 1
# build weight matrix for customer 1220, movie_1 1
# build weight matrix for customer 1222, movie_1 1
# build weight matrix for customer 1223, movie_1 1
# build weight matrix for customer 1227, movie_1 1
# build weight matrix for customer 1232, movie_1 1
# build weight matrix for customer 1242, movie_1 1
# build weight matrix for customer 1244, movie_1 1
# build weight matrix for customer 1246, movie_1 1
# build weight matrix for customer 1252, movie_1 1
# build weight matrix for customer 1254, movie_1 1
# build weight matrix for customer 1258, movie_1 1
# build weight matrix for customer 1261, movie_1 1
# build weight matrix for customer 1267, movie_1 1
# build weight matrix for customer 1268, movie_1 1
# build weight matrix for customer 1279, movie_1 1
# build weight matrix for customer 1280, movie_1 1
# build weight matrix for customer 1281, movie_1 1
# build weight matrix for customer 1289, movie_1 1
# build weight matrix for customer 1302, movie_1 1
# build weight matrix for customer 1305, movie_1 1
# build weight matrix for customer 1307, movie_1 1
# build weight matrix for customer 1309, movie_1 1
# build weight matrix for customer 1311, movie_1 1
# build weight matrix for customer 1312, movie_1 1
# build weight matrix for customer 1317, movie_1 1
# build weight matrix for customer 1322, movie_1 1
# build weight matrix for customer 1323, movie_1 1
# build weight matrix for customer 1325, movie_1 1
# build weight matrix for customer 1326, movie_1 1
# build weight matrix for customer 1327, movie_1 1
# build weight matrix for customer 1329, movie_1 1
# build weight matrix for customer 1338, movie_1 1
# build weight matrix for customer 1339, movie_1 1
# build weight matrix for customer 1350, movie_1 1
# build weight matrix for customer 1357, movie_1 1
# build weight matrix for customer 1367, movie_1 1
# build weight matrix for customer 1368, movie_1 1
# build weight matrix for customer 1371, movie_1 1
# build weight matrix for customer 1376, movie_1 1
# build weight matrix for customer 1377, movie_1 1
# build weight matrix for customer 1379, movie_1 1
# build weight matrix for customer 1382, movie_1 1
# build weight matrix for customer 1385, movie_1 1
# build weight matrix for customer 1387, movie_1 1
# build weight matrix for customer 1392, movie_1 1
# build weight matrix for customer 1400, movie_1 1
# build weight matrix for customer 1406, movie_1 1
# build weight matrix for customer 1421, movie_1 1
# build weight matrix for customer 1423, movie_1 1
# build weight matrix for customer 1432, movie_1 1
# build weight matrix for customer 1436, movie_1 1
# build weight matrix for customer 1437, movie_1 1
# build weight matrix for customer 1438, movie_1 1
# build weight matrix for customer 1444, movie_1 1
# build weight matrix for customer 1446, movie_1 1
# build weight matrix for customer 1449, movie_1 1
# build weight matrix for customer 1453, movie_1 1
# build weight matrix for customer 1455, movie_1 1
# build weight matrix for customer 1456, movie_1 1
# build weight matrix for customer 1458, movie_1 1
# build weight matrix for customer 1459, movie_1 1
# build weight matrix for customer 1460, movie_1 1
# build weight matrix for customer 1468, movie_1 1
# build weight matrix for customer 1471, movie_1 1
# build weight matrix for customer 1475, movie_1 1
# build weight matrix for customer 1478, movie_1 1
# build weight matrix for customer 1481, movie_1 1
# build weight matrix for customer 1488, movie_1 1
# build weight matrix for customer 1496, movie_1 1
# build weight matrix for customer 1497, movie_1 1
# build weight matrix for customer 1507, movie_1 1
# build weight matrix for customer 1509, movie_1 1
# build weight matrix for customer 1514, movie_1 1
# build weight matrix for customer 1515, movie_1 1
# build weight matrix for customer 1516, movie_1 1
# build weight matrix for customer 1518, movie_1 1
# build weight matrix for customer 1519, movie_1 1
# build weight matrix for customer 1523, movie_1 1
# build weight matrix for customer 1525, movie_1 1
# build weight matrix for customer 1526, movie_1 1
# build weight matrix for customer 1530, movie_1 1
# build weight matrix for customer 1532, movie_1 1
# build weight matrix for customer 1534, movie_1 1
# build weight matrix for customer 1539, movie_1 1
# build weight matrix for customer 1547, movie_1 1
# build weight matrix for customer 1550, movie_1 1
# build weight matrix for customer 1554, movie_1 1
# build weight matrix for customer 1555, movie_1 1
# build weight matrix for customer 1556, movie_1 1
# build weight matrix for customer 1557, movie_1 1
# build weight matrix for customer 1559, movie_1 1
# build weight matrix for customer 1568, movie_1 1
# build weight matrix for customer 1570, movie_1 1
# build weight matrix for customer 1573, movie_1 1
# build weight matrix for customer 1574, movie_1 1
# build weight matrix for customer 1577, movie_1 1
# build weight matrix for customer 1584, movie_1 1
# build weight matrix for customer 1588, movie_1 1
# build weight matrix for customer 1600, movie_1 1
# build weight matrix for customer 1602, movie_1 1
# build weight matrix for customer 1604, movie_1 1
# build weight matrix for customer 1607, movie_1 1
# build weight matrix for customer 1608, movie_1 1
# build weight matrix for customer 1616, movie_1 1
# build weight matrix for customer 1617, movie_1 1
# build weight matrix for customer 1619, movie_1 1
# build weight matrix for customer 1620, movie_1 1
# build weight matrix for customer 1626, movie_1 1
# build weight matrix for customer 1628, movie_1 1
# build weight matrix for customer 1630, movie_1 1
# build weight matrix for customer 1635, movie_1 1
# build weight matrix for customer 1641, movie_1 1
# build weight matrix for customer 1644, movie_1 1
# build weight matrix for customer 1645, movie_1 1
# build weight matrix for customer 1646, movie_1 1
# build weight matrix for customer 1650, movie_1 1
# build weight matrix for customer 1655, movie_1 1
# build weight matrix for customer 1662, movie_1 1
# build weight matrix for customer 1665, movie_1 1
# build weight matrix for customer 1670, movie_1 1
# build weight matrix for customer 1676, movie_1 1
# build weight matrix for customer 1677, movie_1 1
# build weight matrix for customer 1678, movie_1 1
# build weight matrix for customer 1686, movie_1 1
# build weight matrix for customer 1688, movie_1 1
# build weight matrix for customer 1689, movie_1 1
# build weight matrix for customer 1695, movie_1 1
# build weight matrix for customer 1703, movie_1 1
# build weight matrix for customer 1704, movie_1 1
# build weight matrix for customer 1706, movie_1 1
# build weight matrix for customer 1715, movie_1 1
# build weight matrix for customer 1716, movie_1 1
# build weight matrix for customer 1721, movie_1 1
# build weight matrix for customer 1727, movie_1 1
# build weight matrix for customer 1729, movie_1 1
# build weight matrix for customer 1730, movie_1 1
# build weight matrix for customer 1734, movie_1 1
# build weight matrix for customer 1736, movie_1 1
# build weight matrix for customer 1741, movie_1 1
# build weight matrix for customer 1743, movie_1 1
# build weight matrix for customer 1744, movie_1 1
# build weight matrix for customer 1745, movie_1 1
# build weight matrix for customer 1748, movie_1 1
# build weight matrix for customer 1750, movie_1 1
# build weight matrix for customer 1755, movie_1 1
# build weight matrix for customer 1758, movie_1 1
# build weight matrix for customer 1759, movie_1 1
# build weight matrix for customer 1764, movie_1 1
# build weight matrix for customer 1768, movie_1 1
# build weight matrix for customer 1771, movie_1 1
# build weight matrix for customer 1774, movie_1 1
# build weight matrix for customer 1777, movie_1 1
# build weight matrix for customer 1779, movie_1 1
# build weight matrix for customer 1784, movie_1 1
# build weight matrix for customer 1786, movie_1 1
# build weight matrix for customer 1789, movie_1 1
# build weight matrix for customer 1790, movie_1 1
# build weight matrix for customer 1791, movie_1 1
# build weight matrix for customer 1800, movie_1 1
# build weight matrix for customer 1808, movie_1 1
# build weight matrix for customer 1809, movie_1 1
# build weight matrix for customer 1812, movie_1 1
# build weight matrix for customer 1819, movie_1 1
# build weight matrix for customer 1820, movie_1 1
# build weight matrix for customer 1825, movie_1 1
# build weight matrix for customer 1831, movie_1 1
# build weight matrix for customer 1836, movie_1 1
# build weight matrix for customer 1840, movie_1 1
# build weight matrix for customer 1844, movie_1 1
# build weight matrix for customer 1847, movie_1 1
# build weight matrix for customer 1849, movie_1 1
# build weight matrix for customer 1851, movie_1 1
# build weight matrix for customer 1854, movie_1 1
# build weight matrix for customer 1866, movie_1 1
# build weight matrix for customer 1868, movie_1 1
# build weight matrix for customer 1880, movie_1 1
# build weight matrix for customer 1881, movie_1 1
# build weight matrix for customer 1885, movie_1 1
# build weight matrix for customer 1886, movie_1 1
# build weight matrix for customer 1891, movie_1 1
# build weight matrix for customer 1896, movie_1 1
# build weight matrix for customer 1906, movie_1 1
# build weight matrix for customer 1918, movie_1 1
# build weight matrix for customer 1925, movie_1 1
# build weight matrix for customer 1930, movie_1 1
# build weight matrix for customer 1931, movie_1 1
# build weight matrix for customer 1941, movie_1 1
# build weight matrix for customer 1942, movie_1 1
# build weight matrix for customer 1945, movie_1 1
# build weight matrix for customer 1952, movie_1 1
# build weight matrix for customer 1953, movie_1 1
# build weight matrix for customer 1954, movie_1 1
# build weight matrix for customer 1955, movie_1 1
# build weight matrix for customer 1960, movie_1 1
# build weight matrix for customer 1963, movie_1 1
# build weight matrix for customer 1964, movie_1 1
# build weight matrix for customer 1966, movie_1 1
# build weight matrix for customer 1969, movie_1 1
# build weight matrix for customer 1972, movie_1 1
# build weight matrix for customer 1974, movie_1 1
# build weight matrix for customer 1980, movie_1 1
# build weight matrix for customer 1990, movie_1 1
# build weight matrix for customer 1993, movie_1 1
# build weight matrix for customer 1997, movie_1 1
# build weight matrix for customer 2004, movie_1 1
# build weight matrix for customer 2010, movie_1 1
# build weight matrix for customer 2015, movie_1 1
# build weight matrix for customer 2017, movie_1 1
# build weight matrix for customer 2019, movie_1 1
# build weight matrix for customer 2024, movie_1 1
# build weight matrix for customer 2025, movie_1 1
# build weight matrix for customer 2026, movie_1 1
# build weight matrix for customer 2027, movie_1 1
# build weight matrix for customer 2031, movie_1 1
# build weight matrix for customer 2034, movie_1 1
# build weight matrix for customer 2035, movie_1 1
# build weight matrix for customer 2038, movie_1 1
# build weight matrix for customer 2045, movie_1 1
# build weight matrix for customer 2047, movie_1 1
# build weight matrix for customer 2048, movie_1 1
# build weight matrix for customer 2051, movie_1 1
# build weight matrix for customer 2056, movie_1 1
# build weight matrix for customer 2058, movie_1 1
# build weight matrix for customer 2062, movie_1 1
# build weight matrix for customer 2067, movie_1 1
# build weight matrix for customer 2068, movie_1 1
# build weight matrix for customer 2071, movie_1 1
# build weight matrix for customer 2072, movie_1 1
# build weight matrix for customer 2075, movie_1 1
# build weight matrix for customer 2076, movie_1 1
# build weight matrix for customer 2081, movie_1 1
# build weight matrix for customer 2090, movie_1 1
# build weight matrix for customer 2096, movie_1 1
# build weight matrix for customer 2099, movie_1 1
# build weight matrix for customer 2100, movie_1 1
# build weight matrix for customer 2101, movie_1 1
# build weight matrix for customer 2104, movie_1 1
# build weight matrix for customer 2106, movie_1 1
# build weight matrix for customer 2109, movie_1 1
# build weight matrix for customer 2115, movie_1 1
# build weight matrix for customer 2118, movie_1 1
# build weight matrix for customer 2120, movie_1 1
# build weight matrix for customer 2126, movie_1 1
# build weight matrix for customer 2131, movie_1 1
# build weight matrix for customer 2138, movie_1 1
# build weight matrix for customer 2140, movie_1 1
# build weight matrix for customer 2143, movie_1 1
# build weight matrix for customer 2147, movie_1 1
# build weight matrix for customer 2149, movie_1 1
# build weight matrix for customer 2153, movie_1 1
# build weight matrix for customer 2156, movie_1 1
# build weight matrix for customer 2161, movie_1 1
# build weight matrix for customer 2163, movie_1 1
# build weight matrix for customer 2164, movie_1 1
# build weight matrix for customer 2171, movie_1 1
# build weight matrix for customer 2174, movie_1 1
# build weight matrix for customer 2176, movie_1 1
# build weight matrix for customer 2184, movie_1 1
# build weight matrix for customer 2188, movie_1 1
# build weight matrix for customer 2191, movie_1 1
# build weight matrix for customer 2193, movie_1 1
# build weight matrix for customer 2197, movie_1 1
# build weight matrix for customer 2200, movie_1 1
# build weight matrix for customer 2202, movie_1 1
# build weight matrix for customer 2215, movie_1 1
# build weight matrix for customer 2226, movie_1 1
# build weight matrix for customer 2227, movie_1 1
# build weight matrix for customer 2232, movie_1 1
# build weight matrix for customer 2239, movie_1 1
# build weight matrix for customer 2242, movie_1 1
# build weight matrix for customer 2243, movie_1 1
# build weight matrix for customer 2244, movie_1 1
# build weight matrix for customer 2245, movie_1 1
# build weight matrix for customer 2246, movie_1 1
# build weight matrix for customer 2250, movie_1 1
# build weight matrix for customer 2252, movie_1 1
# build weight matrix for customer 2253, movie_1 1
# build weight matrix for customer 2254, movie_1 1
# build weight matrix for customer 2257, movie_1 1
# build weight matrix for customer 2261, movie_1 1
# build weight matrix for customer 2263, movie_1 1
# build weight matrix for customer 2265, movie_1 1
# build weight matrix for customer 2269, movie_1 1
# build weight matrix for customer 2270, movie_1 1
# build weight matrix for customer 2273, movie_1 1
# build weight matrix for customer 2274, movie_1 1
# build weight matrix for customer 2278, movie_1 1
# build weight matrix for customer 2281, movie_1 1
# build weight matrix for customer 2288, movie_1 1
# build weight matrix for customer 2290, movie_1 1
# build weight matrix for customer 2294, movie_1 1
# build weight matrix for customer 2295, movie_1 1
# build weight matrix for customer 2301, movie_1 1
# build weight matrix for customer 2302, movie_1 1
# build weight matrix for customer 2303, movie_1 1
# build weight matrix for customer 2307, movie_1 1
# build weight matrix for customer 2312, movie_1 1
# build weight matrix for customer 2314, movie_1 1
# build weight matrix for customer 2320, movie_1 1
# build weight matrix for customer 2321, movie_1 1
# build weight matrix for customer 2323, movie_1 1
# build weight matrix for customer 2324, movie_1 1
# build weight matrix for customer 2331, movie_1 1
# build weight matrix for customer 2332, movie_1 1
# build weight matrix for customer 2333, movie_1 1
# build weight matrix for customer 2338, movie_1 1
# build weight matrix for customer 2349, movie_1 1
# build weight matrix for customer 2350, movie_1 1
# build weight matrix for customer 2357, movie_1 1
# build weight matrix for customer 2359, movie_1 1
# build weight matrix for customer 2361, movie_1 1
# build weight matrix for customer 2362, movie_1 1
# build weight matrix for customer 2365, movie_1 1
# build weight matrix for customer 2368, movie_1 1
# build weight matrix for customer 2370, movie_1 1
# build weight matrix for customer 2374, movie_1 1
# build weight matrix for customer 2377, movie_1 1
# build weight matrix for customer 2380, movie_1 1
# build weight matrix for customer 2382, movie_1 1
# build weight matrix for customer 2384, movie_1 1
# build weight matrix for customer 2386, movie_1 1
# build weight matrix for customer 2392, movie_1 1
# build weight matrix for customer 2394, movie_1 1
# build weight matrix for customer 2402, movie_1 1
# build weight matrix for customer 2407, movie_1 1
# build weight matrix for customer 2408, movie_1 1
# build weight matrix for customer 2409, movie_1 1
# build weight matrix for customer 2412, movie_1 1
# build weight matrix for customer 2422, movie_1 1
# build weight matrix for customer 2423, movie_1 1
# build weight matrix for customer 2427, movie_1 1
# build weight matrix for customer 2428, movie_1 1
# build weight matrix for customer 2430, movie_1 1
# build weight matrix for customer 2433, movie_1 1
# build weight matrix for customer 2435, movie_1 1
# build weight matrix for customer 2436, movie_1 1
# build weight matrix for customer 2438, movie_1 1
# build weight matrix for customer 2441, movie_1 1
# build weight matrix for customer 2445, movie_1 1
# build weight matrix for customer 2451, movie_1 1
# build weight matrix for customer 2473, movie_1 1
# build weight matrix for customer 2484, movie_1 1
# build weight matrix for customer 2485, movie_1 1
# build weight matrix for customer 2487, movie_1 1
# build weight matrix for customer 2494, movie_1 1
# build weight matrix for customer 2496, movie_1 1
# build weight matrix for customer 2497, movie_1 1
# build weight matrix for customer 2502, movie_1 1
# build weight matrix for customer 2503, movie_1 1
# build weight matrix for customer 2505, movie_1 1
# build weight matrix for customer 2506, movie_1 1
# build weight matrix for customer 2515, movie_1 1
# build weight matrix for customer 2517, movie_1 1
# build weight matrix for customer 2520, movie_1 1
# build weight matrix for customer 2523, movie_1 1
# build weight matrix for customer 2532, movie_1 1
# build weight matrix for customer 2542, movie_1 1
# build weight matrix for customer 2544, movie_1 1
# build weight matrix for customer 2549, movie_1 1
# build weight matrix for customer 2550, movie_1 1
# build weight matrix for customer 2555, movie_1 1
# build weight matrix for customer 2556, movie_1 1
# build weight matrix for customer 2558, movie_1 1
# build weight matrix for customer 2564, movie_1 1
# build weight matrix for customer 2565, movie_1 1
# build weight matrix for customer 2569, movie_1 1
# build weight matrix for customer 2570, movie_1 1
# build weight matrix for customer 2575, movie_1 1
# build weight matrix for customer 2582, movie_1 1
# build weight matrix for customer 2583, movie_1 1
# build weight matrix for customer 2584, movie_1 1
# build weight matrix for customer 2597, movie_1 1
# build weight matrix for customer 2599, movie_1 1
# build weight matrix for customer 2601, movie_1 1
# build weight matrix for customer 2602, movie_1 1
# build weight matrix for customer 2605, movie_1 1
# build weight matrix for customer 2607, movie_1 1
# build weight matrix for customer 2616, movie_1 1
# build weight matrix for customer 2618, movie_1 1
# build weight matrix for customer 2622, movie_1 1
# build weight matrix for customer 2631, movie_1 1
# build weight matrix for customer 2633, movie_1 1
# build weight matrix for customer 2636, movie_1 1
# build weight matrix for customer 2640, movie_1 1
# build weight matrix for customer 2641, movie_1 1
# build weight matrix for customer 2643, movie_1 1
# build weight matrix for customer 2652, movie_1 1
# build weight matrix for customer 2654, movie_1 1
# build weight matrix for customer 2656, movie_1 1
# build weight matrix for customer 2661, movie_1 1
# build weight matrix for customer 2663, movie_1 1
# build weight matrix for customer 2669, movie_1 1
# build weight matrix for customer 2670, movie_1 1
# build weight matrix for customer 2675, movie_1 1
# build weight matrix for customer 2676, movie_1 1
# build weight matrix for customer 2678, movie_1 1
# build weight matrix for customer 2680, movie_1 1
# build weight matrix for customer 2681, movie_1 1
# build weight matrix for customer 2682, movie_1 1
# build weight matrix for customer 2684, movie_1 1
# build weight matrix for customer 2686, movie_1 1
# build weight matrix for customer 2695, movie_1 1
# build weight matrix for customer 2696, movie_1 1
# build weight matrix for customer 2697, movie_1 1
# build weight matrix for customer 2698, movie_1 1
# build weight matrix for customer 2700, movie_1 1
# build weight matrix for customer 2702, movie_1 1
# build weight matrix for customer 2712, movie_1 1
# build weight matrix for customer 2713, movie_1 1
# build weight matrix for customer 2715, movie_1 1
# build weight matrix for customer 2718, movie_1 1
# build weight matrix for customer 2728, movie_1 1
# build weight matrix for customer 2732, movie_1 1
# build weight matrix for customer 2733, movie_1 1
# build weight matrix for customer 2735, movie_1 1
# build weight matrix for customer 2737, movie_1 1
# build weight matrix for customer 2742, movie_1 1
# build weight matrix for customer 2743, movie_1 1
# build weight matrix for customer 2745, movie_1 1
# build weight matrix for customer 2746, movie_1 1
# build weight matrix for customer 2748, movie_1 1
# build weight matrix for customer 2751, movie_1 1
# build weight matrix for customer 2752, movie_1 1
# build weight matrix for customer 2756, movie_1 1
# build weight matrix for customer 2757, movie_1 1
# build weight matrix for customer 2762, movie_1 1
# build weight matrix for customer 2766, movie_1 1
# build weight matrix for customer 2771, movie_1 1
# build weight matrix for customer 2773, movie_1 1
# build weight matrix for customer 2780, movie_1 1
# build weight matrix for customer 2784, movie_1 1
# build weight matrix for customer 2800, movie_1 1
# build weight matrix for customer 2805, movie_1 1
# build weight matrix for customer 2807, movie_1 1
# build weight matrix for customer 2812, movie_1 1
# build weight matrix for customer 2813, movie_1 1
# build weight matrix for customer 2818, movie_1 1
# build weight matrix for customer 2826, movie_1 1
# build weight matrix for customer 2832, movie_1 1
# build weight matrix for customer 2836, movie_1 1
# build weight matrix for customer 2839, movie_1 1
# build weight matrix for customer 2848, movie_1 1
# build weight matrix for customer 2851, movie_1 1
# build weight matrix for customer 2855, movie_1 1
# build weight matrix for customer 2865, movie_1 1
# build weight matrix for customer 2866, movie_1 1
# build weight matrix for customer 2868, movie_1 1
# build weight matrix for customer 2869, movie_1 1
# build weight matrix for customer 2871, movie_1 1
# build weight matrix for customer 2874, movie_1 1
# build weight matrix for customer 2875, movie_1 1
# build weight matrix for customer 2882, movie_1 1
# build weight matrix for customer 2885, movie_1 1
# build weight matrix for customer 2886, movie_1 1
# build weight matrix for customer 2891, movie_1 1
# build weight matrix for customer 2893, movie_1 1
# build weight matrix for customer 2894, movie_1 1
# build weight matrix for customer 2895, movie_1 1
# build weight matrix for customer 2899, movie_1 1
# build weight matrix for customer 2902, movie_1 1
# build weight matrix for customer 2909, movie_1 1
# build weight matrix for customer 2912, movie_1 1
# build weight matrix for customer 2914, movie_1 1
# build weight matrix for customer 2916, movie_1 1
# build weight matrix for customer 2928, movie_1 1
# build weight matrix for customer 2937, movie_1 1
# build weight matrix for customer 2944, movie_1 1
# build weight matrix for customer 2946, movie_1 1
# build weight matrix for customer 2948, movie_1 1
# build weight matrix for customer 2950, movie_1 1
# build weight matrix for customer 2959, movie_1 1
# build weight matrix for customer 2966, movie_1 1
# build weight matrix for customer 2979, movie_1 1
# build weight matrix for customer 2988, movie_1 1
# build weight matrix for customer 2990, movie_1 1
# build weight matrix for customer 2995, movie_1 1
# build weight matrix for customer 3000, movie_1 1
# build weight matrix for customer 3002, movie_1 1
# build weight matrix for customer 3003, movie_1 1
# build weight matrix for customer 3010, movie_1 1
# build weight matrix for customer 3013, movie_1 1
# build weight matrix for customer 3017, movie_1 1
# build weight matrix for customer 3020, movie_1 1
# build weight matrix for customer 3029, movie_1 1
# build weight matrix for customer 3032, movie_1 1
# build weight matrix for customer 3033, movie_1 1
# build weight matrix for customer 3035, movie_1 1
# build weight matrix for customer 3037, movie_1 1
# build weight matrix for customer 3041, movie_1 1
# build weight matrix for customer 3042, movie_1 1
# build weight matrix for customer 3045, movie_1 1
# build weight matrix for customer 3047, movie_1 1
# build weight matrix for customer 3048, movie_1 1
# build weight matrix for customer 3052, movie_1 1
# build weight matrix for customer 3054, movie_1 1
# build weight matrix for customer 3057, movie_1 1
# build weight matrix for customer 3058, movie_1 1
# build weight matrix for customer 3065, movie_1 1
# build weight matrix for customer 3070, movie_1 1
# build weight matrix for customer 3073, movie_1 1
# build weight matrix for customer 3076, movie_1 1
# build weight matrix for customer 3081, movie_1 1
# build weight matrix for customer 3086, movie_1 1
# build weight matrix for customer 3088, movie_1 1
# build weight matrix for customer 3089, movie_1 1
# build weight matrix for customer 3092, movie_1 1
# build weight matrix for customer 3093, movie_1 1
# build weight matrix for customer 3105, movie_1 1
# build weight matrix for customer 3126, movie_1 1
# build weight matrix for customer 3134, movie_1 1
# build weight matrix for customer 3145, movie_1 1
# build weight matrix for customer 3146, movie_1 1
# build weight matrix for customer 3148, movie_1 1
# build weight matrix for customer 3152, movie_1 1
# build weight matrix for customer 3154, movie_1 1
# build weight matrix for customer 3166, movie_1 1
# build weight matrix for customer 3170, movie_1 1
# build weight matrix for customer 3172, movie_1 1
# build weight matrix for customer 3178, movie_1 1
# build weight matrix for customer 3179, movie_1 1
# build weight matrix for customer 3182, movie_1 1
# build weight matrix for customer 3184, movie_1 1
# build weight matrix for customer 3186, movie_1 1
# build weight matrix for customer 3189, movie_1 1
# build weight matrix for customer 3192, movie_1 1
# build weight matrix for customer 3195, movie_1 1
# build weight matrix for customer 3196, movie_1 1
# build weight matrix for customer 3197, movie_1 1
# build weight matrix for customer 3203, movie_1 1
# build weight matrix for customer 3208, movie_1 1
# build weight matrix for customer 3212, movie_1 1
# build weight matrix for customer 3217, movie_1 1
# build weight matrix for customer 3218, movie_1 1
# build weight matrix for customer 3219, movie_1 1
# build weight matrix for customer 3222, movie_1 1
# build weight matrix for customer 3227, movie_1 1
# build weight matrix for customer 3228, movie_1 1
# build weight matrix for customer 3231, movie_1 1
# build weight matrix for customer 3235, movie_1 1
# build weight matrix for customer 3236, movie_1 1
# build weight matrix for customer 3241, movie_1 1
# build weight matrix for customer 3245, movie_1 1
# build weight matrix for customer 3246, movie_1 1
# build weight matrix for customer 3254, movie_1 1
# build weight matrix for customer 3255, movie_1 1
# build weight matrix for customer 3263, movie_1 1
# build weight matrix for customer 3264, movie_1 1
# build weight matrix for customer 3265, movie_1 1
# build weight matrix for customer 3268, movie_1 1
# build weight matrix for customer 3269, movie_1 1
# build weight matrix for customer 3272, movie_1 1
# build weight matrix for customer 3273, movie_1 1
# build weight matrix for customer 3277, movie_1 1
# build weight matrix for customer 3284, movie_1 1
# build weight matrix for customer 3288, movie_1 1
# build weight matrix for customer 3289, movie_1 1
# build weight matrix for customer 3293, movie_1 1
# build weight matrix for customer 3294, movie_1 1
# build weight matrix for customer 3295, movie_1 1
# build weight matrix for customer 3301, movie_1 1
# build weight matrix for customer 3305, movie_1 1
# build weight matrix for customer 3311, movie_1 1
# build weight matrix for customer 3313, movie_1 1
# build weight matrix for customer 3316, movie_1 1
# build weight matrix for customer 3317, movie_1 1
# build weight matrix for customer 3318, movie_1 1
# build weight matrix for customer 3320, movie_1 1
# build weight matrix for customer 3323, movie_1 1
# build weight matrix for customer 3325, movie_1 1
# build weight matrix for customer 3328, movie_1 1
# build weight matrix for customer 3338, movie_1 1
# build weight matrix for customer 3350, movie_1 1
# build weight matrix for customer 3352, movie_1 1
# build weight matrix for customer 3353, movie_1 1
# build weight matrix for customer 3360, movie_1 1
# build weight matrix for customer 3371, movie_1 1
# build weight matrix for customer 3376, movie_1 1
# build weight matrix for customer 3380, movie_1 1
# build weight matrix for customer 3381, movie_1 1
# build weight matrix for customer 3382, movie_1 1
# build weight matrix for customer 3383, movie_1 1
# build weight matrix for customer 3384, movie_1 1
# build weight matrix for customer 3385, movie_1 1
# build weight matrix for customer 3389, movie_1 1
# build weight matrix for customer 3391, movie_1 1
# build weight matrix for customer 3392, movie_1 1
# build weight matrix for customer 3393, movie_1 1
# build weight matrix for customer 3398, movie_1 1
# build weight matrix for customer 3402, movie_1 1
# build weight matrix for customer 3404, movie_1 1
# build weight matrix for customer 3407, movie_1 1
# build weight matrix for customer 3408, movie_1 1
# build weight matrix for customer 3412, movie_1 1
# build weight matrix for customer 3415, movie_1 1
# build weight matrix for customer 3426, movie_1 1
# build weight matrix for customer 3427, movie_1 1
# build weight matrix for customer 3430, movie_1 1
# build weight matrix for customer 3434, movie_1 1
# build weight matrix for customer 3436, movie_1 1
# build weight matrix for customer 3439, movie_1 1
# build weight matrix for customer 3443, movie_1 1
# build weight matrix for customer 3445, movie_1 1
# build weight matrix for customer 3459, movie_1 1
# build weight matrix for customer 3461, movie_1 1
# build weight matrix for customer 3462, movie_1 1
# build weight matrix for customer 3469, movie_1 1
# build weight matrix for customer 3471, movie_1 1
# build weight matrix for customer 3474, movie_1 1
# build weight matrix for customer 3479, movie_1 1
# build weight matrix for customer 3486, movie_1 1
# build weight matrix for customer 3489, movie_1 1
# build weight matrix for customer 3490, movie_1 1
# build weight matrix for customer 3492, movie_1 1
# build weight matrix for customer 3497, movie_1 1
# build weight matrix for customer 3499, movie_1 1
# build weight matrix for customer 3505, movie_1 1
# build weight matrix for customer 3513, movie_1 1
# build weight matrix for customer 3514, movie_1 1
# build weight matrix for customer 3515, movie_1 1
# build weight matrix for customer 3516, movie_1 1
# build weight matrix for customer 3524, movie_1 1
# build weight matrix for customer 3528, movie_1 1
# build weight matrix for customer 3532, movie_1 1
# build weight matrix for customer 3534, movie_1 1
# build weight matrix for customer 3537, movie_1 1
# build weight matrix for customer 3540, movie_1 1
# build weight matrix for customer 3549, movie_1 1
# build weight matrix for customer 3554, movie_1 1
# build weight matrix for customer 3557, movie_1 1
# build weight matrix for customer 3567, movie_1 1
# build weight matrix for customer 3576, movie_1 1
# build weight matrix for customer 3578, movie_1 1
# build weight matrix for customer 3580, movie_1 1
# build weight matrix for customer 3586, movie_1 1
# build weight matrix for customer 3592, movie_1 1
# build weight matrix for customer 3593, movie_1 1
# build weight matrix for customer 3596, movie_1 1
# build weight matrix for customer 3600, movie_1 1
# build weight matrix for customer 3603, movie_1 1
# build weight matrix for customer 3606, movie_1 1
# build weight matrix for customer 3617, movie_1 1
# build weight matrix for customer 3618, movie_1 1
# build weight matrix for customer 3624, movie_1 1
# build weight matrix for customer 3628, movie_1 1
# build weight matrix for customer 3629, movie_1 1
# build weight matrix for customer 3630, movie_1 1
# build weight matrix for customer 3632, movie_1 1
# build weight matrix for customer 3633, movie_1 1
# build weight matrix for customer 3636, movie_1 1
# build weight matrix for customer 3639, movie_1 1
# build weight matrix for customer 3646, movie_1 1
# build weight matrix for customer 3651, movie_1 1
# build weight matrix for customer 3654, movie_1 1
# build weight matrix for customer 3659, movie_1 1
# build weight matrix for customer 3664, movie_1 1
# build weight matrix for customer 3667, movie_1 1
# build weight matrix for customer 3671, movie_1 1
# build weight matrix for customer 3673, movie_1 1
# build weight matrix for customer 3676, movie_1 1
# build weight matrix for customer 3684, movie_1 1
# build weight matrix for customer 3687, movie_1 1
# build weight matrix for customer 3697, movie_1 1
# build weight matrix for customer 3701, movie_1 1
# build weight matrix for customer 3705, movie_1 1
# build weight matrix for customer 3706, movie_1 1
# build weight matrix for customer 3709, movie_1 1
# build weight matrix for customer 3713, movie_1 1
# build weight matrix for customer 3715, movie_1 1
# build weight matrix for customer 3726, movie_1 1
# build weight matrix for customer 3727, movie_1 1
# build weight matrix for customer 3731, movie_1 1
# build weight matrix for customer 3746, movie_1 1
# build weight matrix for customer 3748, movie_1 1
# build weight matrix for customer 3751, movie_1 1
# build weight matrix for customer 3755, movie_1 1
# build weight matrix for customer 3764, movie_1 1
# build weight matrix for customer 3765, movie_1 1
# build weight matrix for customer 3773, movie_1 1
# build weight matrix for customer 3774, movie_1 1
# build weight matrix for customer 3776, movie_1 1
# build weight matrix for customer 3779, movie_1 1
# build weight matrix for customer 3818, movie_1 1
# build weight matrix for customer 3821, movie_1 1
# build weight matrix for customer 3827, movie_1 1
# build weight matrix for customer 3842, movie_1 1
# build weight matrix for customer 3848, movie_1 1
# build weight matrix for customer 3850, movie_1 1
# build weight matrix for customer 3851, movie_1 1
# build weight matrix for customer 3858, movie_1 1
# build weight matrix for customer 3870, movie_1 1
# build weight matrix for customer 3871, movie_1 1
# build weight matrix for customer 3872, movie_1 1
# build weight matrix for customer 3874, movie_1 1
# build weight matrix for customer 3876, movie_1 1
# build weight matrix for customer 3886, movie_1 1
# build weight matrix for customer 3895, movie_1 1
# build weight matrix for customer 3899, movie_1 1
# build weight matrix for customer 3901, movie_1 1
# ...
# build weight matrix for customer 5881, movie_1 50
# build weight matrix for customer 5882, movie_1 50
# build weight matrix for customer 5892, movie_1 50
# build weight matrix for customer 5894, movie_1 50
# build weight matrix for customer 5897, movie_1 50
# build weight matrix for customer 5898, movie_1 50
# build weight matrix for customer 5900, movie_1 50
# build weight matrix for customer 5904, movie_1 50
# build weight matrix for customer 5907, movie_1 50
# build weight matrix for customer 5908, movie_1 50
# build weight matrix for customer 5920, movie_1 50
# build weight matrix for customer 5926, movie_1 50
# build weight matrix for customer 5927, movie_1 50
# build weight matrix for customer 5928, movie_1 50
# build weight matrix for customer 5936, movie_1 50
# build weight matrix for customer 5938, movie_1 50
# build weight matrix for customer 5946, movie_1 50
# build weight matrix for customer 5951, movie_1 50
# build weight matrix for customer 5959, movie_1 50
# build weight matrix for customer 5966, movie_1 50
# build weight matrix for customer 5967, movie_1 50
# build weight matrix for customer 5968, movie_1 50
# build weight matrix for customer 5979, movie_1 50
# build weight matrix for customer 5983, movie_1 50
# build weight matrix for customer 5991, movie_1 50
# build weight matrix for customer 6005, movie_1 50
# build weight matrix for customer 6007, movie_1 50
# build weight matrix for customer 6008, movie_1 50
# build weight matrix for customer 6011, movie_1 50
# build weight matrix for customer 6012, movie_1 50
# build weight matrix for customer 6017, movie_1 50
# build weight matrix for customer 6027, movie_1 50
# build weight matrix for customer 6030, movie_1 50
# build weight matrix for customer 6034, movie_1 50
# build weight matrix for customer 6039, movie_1 50
# build weight matrix for customer 6045, movie_1 50
# build weight matrix for customer 6046, movie_1 50
# build weight matrix for customer 6047, movie_1 50
# build weight matrix for customer 6050, movie_1 50
# build weight matrix for customer 6052, movie_1 50
# build weight matrix for customer 6053, movie_1 50
# build weight matrix for customer 6057, movie_1 50
# build weight matrix for customer 6060, movie_1 50
# build weight matrix for customer 6073, movie_1 50
# build weight matrix for customer 6074, movie_1 50
# build weight matrix for customer 6075, movie_1 50
# build weight matrix for customer 6077, movie_1 50
# build weight matrix for customer 6081, movie_1 50
# build weight matrix for customer 6082, movie_1 50
# build weight matrix for customer 6085, movie_1 50
# build weight matrix for customer 6088, movie_1 50
# build weight matrix for customer 6089, movie_1 50
# build weight matrix for customer 6090, movie_1 50
# build weight matrix for customer 6093, movie_1 50
# build weight matrix for customer 6095, movie_1 50
# build weight matrix for customer 6097, movie_1 50
# build weight matrix for customer 6098, movie_1 50
# build weight matrix for customer 6099, movie_1 50
# build weight matrix for customer 6112, movie_1 50
# build weight matrix for customer 6114, movie_1 50
# build weight matrix for customer 6116, movie_1 50
# build weight matrix for customer 6119, movie_1 50
# build weight matrix for customer 6127, movie_1 50
# build weight matrix for customer 6130, movie_1 50
# build weight matrix for customer 6132, movie_1 50
# build weight matrix for customer 6135, movie_1 50
# build weight matrix for customer 6137, movie_1 50
# build weight matrix for customer 6141, movie_1 50
# build weight matrix for customer 6147, movie_1 50
# build weight matrix for customer 6148, movie_1 50
# build weight matrix for customer 6152, movie_1 50
# build weight matrix for customer 6153, movie_1 50
# build weight matrix for customer 6164, movie_1 50
# build weight matrix for customer 6168, movie_1 50
# build weight matrix for customer 6169, movie_1 50
# build weight matrix for customer 6171, movie_1 50
# build weight matrix for customer 6172, movie_1 50
# build weight matrix for customer 6177, movie_1 50
# build weight matrix for customer 6191, movie_1 50
# build weight matrix for customer 6193, movie_1 50
# build weight matrix for customer 6200, movie_1 50
# build weight matrix for customer 6220, movie_1 50
# build weight matrix for customer 6225, movie_1 50
# build weight matrix for customer 6232, movie_1 50
# build weight matrix for customer 6234, movie_1 50
# build weight matrix for customer 6238, movie_1 50
# build weight matrix for customer 6239, movie_1 50
# build weight matrix for customer 6244, movie_1 50
# build weight matrix for customer 6246, movie_1 50
# build weight matrix for customer 6247, movie_1 50
# build weight matrix for customer 6257, movie_1 50
# build weight matrix for customer 6273, movie_1 50
# build weight matrix for customer 6275, movie_1 50
# build weight matrix for customer 6277, movie_1 50
# build weight matrix for customer 6282, movie_1 50
# build weight matrix for customer 6286, movie_1 50
# build weight matrix for customer 6291, movie_1 50
# build weight matrix for customer 6296, movie_1 50
# build weight matrix for customer 6299, movie_1 50
# build weight matrix for customer 6309, movie_1 50
# build weight matrix for customer 6321, movie_1 50
# build weight matrix for customer 6326, movie_1 50
# build weight matrix for customer 6332, movie_1 50
# build weight matrix for customer 6333, movie_1 50
# build weight matrix for customer 6339, movie_1 50
# build weight matrix for customer 6345, movie_1 50
# build weight matrix for customer 6346, movie_1 50
# build weight matrix for customer 6349, movie_1 50
# build weight matrix for customer 6351, movie_1 50
# build weight matrix for customer 6356, movie_1 50
# build weight matrix for customer 6361, movie_1 50
# build weight matrix for customer 6366, movie_1 50
# build weight matrix for customer 6368, movie_1 50
# build weight matrix for customer 6372, movie_1 50
# build weight matrix for customer 6376, movie_1 50
# build weight matrix for customer 6377, movie_1 50
# build weight matrix for customer 6379, movie_1 50
# build weight matrix for customer 6381, movie_1 50
# build weight matrix for customer 6384, movie_1 50
# build weight matrix for customer 6388, movie_1 50
# build weight matrix for customer 6389, movie_1 50
# build weight matrix for customer 6392, movie_1 50
# build weight matrix for customer 6405, movie_1 50
# build weight matrix for customer 6418, movie_1 50
# build weight matrix for customer 6420, movie_1 50
# build weight matrix for customer 6421, movie_1 50
# build weight matrix for customer 6423, movie_1 50
# build weight matrix for customer 6431, movie_1 50
# build weight matrix for customer 6433, movie_1 50
# build weight matrix for customer 6447, movie_1 50
# build weight matrix for customer 6453, movie_1 50
# build weight matrix for customer 6454, movie_1 50
# build weight matrix for customer 6455, movie_1 50
# build weight matrix for customer 6462, movie_1 50
# build weight matrix for customer 6465, movie_1 50
# build weight matrix for customer 6469, movie_1 50
# build weight matrix for customer 6477, movie_1 50
# build weight matrix for customer 6479, movie_1 50
# build weight matrix for customer 6480, movie_1 50
# build weight matrix for customer 6486, movie_1 50
# build weight matrix for customer 6490, movie_1 50
# build weight matrix for customer 6497, movie_1 50
# build weight matrix for customer 6500, movie_1 50
# build weight matrix for customer 6509, movie_1 50
# build weight matrix for customer 6510, movie_1 50
# build weight matrix for customer 6514, movie_1 50
# build weight matrix for customer 6522, movie_1 50
# build weight matrix for customer 6525, movie_1 50
# build weight matrix for customer 6530, movie_1 50
# build weight matrix for customer 6531, movie_1 50
# build weight matrix for customer 6533, movie_1 50
# build weight matrix for customer 6538, movie_1 50
# build weight matrix for customer 6547, movie_1 50
# build weight matrix for customer 6553, movie_1 50
# build weight matrix for customer 6554, movie_1 50
# build weight matrix for customer 6566, movie_1 50
# build weight matrix for customer 6568, movie_1 50
# build weight matrix for customer 6578, movie_1 50
# build weight matrix for customer 6580, movie_1 50
# build weight matrix for customer 6585, movie_1 50
# build weight matrix for customer 6586, movie_1 50
# build weight matrix for customer 6593, movie_1 50
# build weight matrix for customer 6597, movie_1 50
# build weight matrix for customer 6600, movie_1 50
# build weight matrix for customer 6602, movie_1 50
# build weight matrix for customer 6604, movie_1 50
# build weight matrix for customer 6611, movie_1 50
# build weight matrix for customer 6618, movie_1 50
# build weight matrix for customer 6620, movie_1 50
# build weight matrix for customer 6624, movie_1 50
# build weight matrix for customer 6632, movie_1 50
# build weight matrix for customer 6634, movie_1 50
# build weight matrix for customer 6635, movie_1 50
# build weight matrix for customer 6636, movie_1 50
# build weight matrix for customer 6641, movie_1 50
# build weight matrix for customer 6652, movie_1 50
# build weight matrix for customer 6661, movie_1 50
# build weight matrix for customer 6662, movie_1 50
# build weight matrix for customer 6663, movie_1 50
# build weight matrix for customer 6667, movie_1 50
# build weight matrix for customer 6669, movie_1 50
# build weight matrix for customer 6674, movie_1 50
# build weight matrix for customer 6679, movie_1 50
# build weight matrix for customer 6685, movie_1 50
# build weight matrix for customer 6689, movie_1 50
# build weight matrix for customer 6703, movie_1 50
# build weight matrix for customer 6717, movie_1 50
# build weight matrix for customer 6722, movie_1 50
# build weight matrix for customer 6727, movie_1 50
# build weight matrix for customer 6732, movie_1 50
# build weight matrix for customer 6733, movie_1 50
# build weight matrix for customer 6737, movie_1 50
# build weight matrix for customer 6739, movie_1 50
# build weight matrix for customer 6743, movie_1 50
# build weight matrix for customer 6745, movie_1 50
# build weight matrix for customer 6755, movie_1 50
# build weight matrix for customer 6757, movie_1 50
# build weight matrix for customer 6761, movie_1 50
# build weight matrix for customer 6764, movie_1 50
# build weight matrix for customer 6773, movie_1 50
# build weight matrix for customer 6774, movie_1 50
# build weight matrix for customer 6783, movie_1 50
# build weight matrix for customer 6784, movie_1 50
# build weight matrix for customer 6803, movie_1 50
# build weight matrix for customer 6804, movie_1 50
# build weight matrix for customer 6813, movie_1 50
# build weight matrix for customer 6815, movie_1 50
# build weight matrix for customer 6824, movie_1 50
# build weight matrix for customer 6843, movie_1 50
# build weight matrix for customer 6847, movie_1 50
# build weight matrix for customer 6849, movie_1 50
# build weight matrix for customer 6852, movie_1 50
# build weight matrix for customer 6855, movie_1 50
# build weight matrix for customer 6861, movie_1 50
# build weight matrix for customer 6870, movie_1 50
# build weight matrix for customer 6873, movie_1 50
# build weight matrix for customer 6874, movie_1 50
# build weight matrix for customer 6881, movie_1 50
# build weight matrix for customer 6888, movie_1 50
# build weight matrix for customer 6889, movie_1 50
# build weight matrix for customer 6890, movie_1 50
# build weight matrix for customer 6893, movie_1 50
# build weight matrix for customer 6897, movie_1 50
# build weight matrix for customer 6903, movie_1 50
# build weight matrix for customer 6904, movie_1 50
# build weight matrix for customer 6906, movie_1 50
# build weight matrix for customer 6908, movie_1 50
# build weight matrix for customer 6910, movie_1 50
# build weight matrix for customer 6912, movie_1 50
# build weight matrix for customer 6917, movie_1 50
# build weight matrix for customer 6921, movie_1 50
# build weight matrix for customer 6924, movie_1 50
# build weight matrix for customer 6931, movie_1 50
# build weight matrix for customer 6934, movie_1 50
# build weight matrix for customer 6938, movie_1 50
# build weight matrix for customer 6942, movie_1 50
# build weight matrix for customer 6944, movie_1 50
# build weight matrix for customer 6950, movie_1 50
# build weight matrix for customer 6952, movie_1 50
# build weight matrix for customer 6955, movie_1 50
# build weight matrix for customer 6961, movie_1 50
# build weight matrix for customer 6964, movie_1 50
# build weight matrix for customer 6966, movie_1 50
# build weight matrix for customer 6971, movie_1 50
# build weight matrix for customer 6976, movie_1 50
# build weight matrix for customer 6980, movie_1 50
# build weight matrix for customer 6985, movie_1 50
# build weight matrix for customer 6987, movie_1 50
# build weight matrix for customer 6988, movie_1 50
# build weight matrix for customer 6996, movie_1 50
# build weight matrix for customer 7000, movie_1 50
# build weight matrix for customer 7003, movie_1 50
# build weight matrix for customer 7006, movie_1 50
# build weight matrix for customer 7010, movie_1 50
# build weight matrix for customer 7013, movie_1 50
# build weight matrix for customer 7021, movie_1 50
# build weight matrix for customer 7036, movie_1 50
# build weight matrix for customer 7040, movie_1 50
# build weight matrix for customer 7044, movie_1 50
# build weight matrix for customer 7046, movie_1 50
# build weight matrix for customer 7048, movie_1 50
# build weight matrix for customer 7049, movie_1 50
# build weight matrix for customer 7050, movie_1 50
# build weight matrix for customer 7056, movie_1 50
# build weight matrix for customer 7061, movie_1 50
# build weight matrix for customer 7065, movie_1 50
# build weight matrix for customer 7067, movie_1 50
# build weight matrix for customer 7077, movie_1 50
# build weight matrix for customer 7079, movie_1 50
# build weight matrix for customer 7085, movie_1 50
# build weight matrix for customer 7088, movie_1 50
# build weight matrix for customer 7090, movie_1 50
# build weight matrix for customer 7093, movie_1 50
# build weight matrix for customer 7103, movie_1 50
# build weight matrix for customer 7107, movie_1 50
# build weight matrix for customer 7108, movie_1 50
# build weight matrix for customer 7111, movie_1 50
# build weight matrix for customer 7113, movie_1 50
# build weight matrix for customer 7115, movie_1 50
# build weight matrix for customer 7117, movie_1 50
# calculate weight movie_1 50, movie_2 1
# calculate weight movie_1 50, movie_2 2
# calculate weight movie_1 50, movie_2 3
# calculate weight movie_1 50, movie_2 4
# calculate weight movie_1 50, movie_2 5
# calculate weight movie_1 50, movie_2 6
# calculate weight movie_1 50, movie_2 7
# calculate weight movie_1 50, movie_2 8
# calculate weight movie_1 50, movie_2 9
# calculate weight movie_1 50, movie_2 10
# calculate weight movie_1 50, movie_2 11
# calculate weight movie_1 50, movie_2 12
# calculate weight movie_1 50, movie_2 13
# calculate weight movie_1 50, movie_2 14
# calculate weight movie_1 50, movie_2 15
# calculate weight movie_1 50, movie_2 16
# calculate weight movie_1 50, movie_2 17
# calculate weight movie_1 50, movie_2 18
# calculate weight movie_1 50, movie_2 19
# calculate weight movie_1 50, movie_2 20
# calculate weight movie_1 50, movie_2 21
# calculate weight movie_1 50, movie_2 22
# calculate weight movie_1 50, movie_2 23
# calculate weight movie_1 50, movie_2 24
# calculate weight movie_1 50, movie_2 25
# calculate weight movie_1 50, movie_2 26
# calculate weight movie_1 50, movie_2 27
# calculate weight movie_1 50, movie_2 28
# calculate weight movie_1 50, movie_2 29
# calculate weight movie_1 50, movie_2 30
# calculate weight movie_1 50, movie_2 31
# calculate weight movie_1 50, movie_2 32
# calculate weight movie_1 50, movie_2 33
# calculate weight movie_1 50, movie_2 34
# calculate weight movie_1 50, movie_2 35
# calculate weight movie_1 50, movie_2 36
# calculate weight movie_1 50, movie_2 37
# calculate weight movie_1 50, movie_2 38
# calculate weight movie_1 50, movie_2 39
# calculate weight movie_1 50, movie_2 40
# calculate weight movie_1 50, movie_2 41
# calculate weight movie_1 50, movie_2 42
# calculate weight movie_1 50, movie_2 43
# calculate weight movie_1 50, movie_2 44
# calculate weight movie_1 50, movie_2 45
# calculate weight movie_1 50, movie_2 46
# calculate weight movie_1 50, movie_2 47
# calculate weight movie_1 50, movie_2 48
# calculate weight movie_1 50, movie_2 49

# %%
weight_matrix.head()
# Out:
#    movie_1  movie_2    weight
# 0      1.0      2.0  0.363705
# 1      1.0      3.0  0.171153
# 2      1.0      4.0  0.168094
# 3      1.0      5.0  0.356217
# 4      1.0      6.0  0.113959

# %%
weight_matrix.shape
# Out:
# (2378, 3)

# %%
weight_matrix.head()
# Out:
#    movie_1  movie_2    weight
# 0      1.0      2.0  0.363705
# 1      1.0      3.0  0.171153
# 2      1.0      4.0  0.168094
# 3      1.0      5.0  0.356217
# 4      1.0      6.0  0.113959

# %%
predict(1, 3, weight_matrix, adjusted_ratings, rating_mean)
# Out:
# 3.1344952110013615

# %%
distinct_movies = np.unique(ratings['movieId'])

# %%
distinct_movies=pd.DataFrame(distinct_movies)

# %%
distinct_movies.columns=["MovieId"]

# %%
table2=distinct_movies.copy()
table2= pd.get_dummies(table2, drop_first=True)
table2.head()
# Out:
#    MovieId
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
def predict(userId, w_matrix, adjusted_ratings, rating_mean):
   # fix missing mean rating which was caused by no ratings for the given movie
   # mean_rating exists for movieId
   Prediction_matrix_columns = ['movieID', 'Prediction']
   Prediction_matrix=pd.DataFrame(columns= Prediction_matrix_columns)

    for movieId in list(distinct_movies['MovieId']):
         if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
             mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
         else:
             mean_rating = 2.5

   # calculate the rating of the given movie by the given user
         user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
         user_distinct_movies = np.unique(user_other_ratings['movieId'])
         sum_weighted_other_ratings = 0
         sum_weghts = 0
         for movie_j in user_distinct_movies:
           if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
               rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
           else:
               rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
           w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
           if w_movie_1_2.shape[0] > 0:
               user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
               sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
               sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])

   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
        if sum_weghts == 0:
                predicted_rating = mean_rating
   # sum_weights is bigger than 0
        else:
                predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts
      
            Prediction_matrix = Prediction_matrix.append(pd.Series([ movieId, predicted_rating], index=Prediction_matrix_columns), ignore_index=True)

    return Prediction_matrix
# Out:
#   File "<tokenize>", line 32
#     if sum_weghts == 0:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def predict(userId, w_matrix, adjusted_ratings, rating_mean):
   Prediction_matrix_columns = ['movieID', 'Prediction']
   Prediction_matrix=pd.DataFrame(columns= Prediction_matrix_columns)

   for movieId in list(distinct_movies['MovieId']):
         if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
             mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
         else:
             mean_rating = 2.5

   # calculate the rating of the given movie by the given user
         user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
         user_distinct_movies = np.unique(user_other_ratings['movieId'])
         sum_weighted_other_ratings = 0
         sum_weghts = 0
         for movie_j in user_distinct_movies:
           if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
               rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
           else:
               rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
           w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
           if w_movie_1_2.shape[0] > 0:
               user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
               sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
               sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])
   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
        if sum_weghts == 0:
             predicted_rating = mean_rating
   # sum_weights is bigger than 0
        else:
                predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts
        Prediction_matrix = Prediction_matrix.append(pd.Series([ movieId, predicted_rating], index=Prediction_matrix_columns), ignore_index=True)

    return Prediction_matrix
# Out:
#   File "<tokenize>", line 29
#     if sum_weghts == 0:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def predict(userId, w_matrix, adjusted_ratings, rating_mean):
   # fix missing mean rating which was caused by no ratings for the given movie
   # mean_rating exists for movieId
   Prediction_matrix_columns = ['movieID', 'Prediction']
   Prediction_matrix=pd.DataFrame(columns= Prediction_matrix_columns)

    for movieId in list(distinct_movies['MovieId']):
         if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
             mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
         else:
             mean_rating = 2.5

   # calculate the rating of the given movie by the given user
         user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
         user_distinct_movies = np.unique(user_other_ratings['movieId'])
         sum_weighted_other_ratings = 0
         sum_weghts = 0
         for movie_j in user_distinct_movies:
           if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
               rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
           else:
               rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
           w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
           if w_movie_1_2.shape[0] > 0:
               user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
               sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
               sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])

   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
        if sum_weghts == 0:
                predicted_rating = mean_rating
   # sum_weights is bigger than 0
        else:
                predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts
      
            Prediction_matrix = Prediction_matrix.append(pd.Series([ movieId, predicted_rating], index=Prediction_matrix_columns), ignore_index=True)

    return Prediction_matrix

# %%
# calculate the predicted ratings
def predict(userId, movieId, w_matrix, adjusted_ratings, rating_mean):
   # fix missing mean rating which was caused by no ratings for the given movie
 Prediction_matrix_columns = ['movieID', 'Prediction']
 Prediction_matrix=pd.DataFrame(columns= Prediction_matrix_columns)   
    # mean_rating exists for movieId
   if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
       mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
   else:
       mean_rating = 2.5

   # calculate the rating of the given movie by the given user
   user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
   user_distinct_movies = np.unique(user_other_ratings['movieId'])
   sum_weighted_other_ratings = 0
   sum_weghts = 0
   for movie_j in user_distinct_movies:
       if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
           rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
       else:
           rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
       w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
       if w_movie_1_2.shape[0] > 0:
           user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
           sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
           sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])

   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
   if sum_weghts == 0:
       predicted_rating = mean_rating
   # sum_weights is bigger than 0
   else:
       predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts

   return predicted_rating
# Out:
#   File "<ipython-input-98-819c7c0bdb8e>", line 7
#     if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
#     ^
# IndentationError: unexpected indent

# %%
def predict(userId, movieId, w_matrix, adjusted_ratings, rating_mean):
   # fix missing mean rating which was caused by no ratings for the given movie
   Prediction_matrix_columns = ['movieID', 'Prediction']
    Prediction_matrix=pd.DataFrame(columns= Prediction_matrix_columns)
    # mean_rating exists for movieId
   for movieId in list(distinct_movies['MovieId']):
    if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
        mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
    else:
        mean_rating = 2.5

   # calculate the rating of the given movie by the given user
    user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
    user_distinct_movies = np.unique(user_other_ratings['movieId'])
    sum_weighted_other_ratings = 0
    sum_weghts = 0
    for movie_j in user_distinct_movies:
        if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
            rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
        else:
            rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
        w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
        if w_movie_1_2.shape[0] > 0:
            user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
            sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
            sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])

   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
    if sum_weghts == 0:
        predicted_rating = mean_rating
    # sum_weights is bigger than 0
    else:
        predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts
    Prediction_matrix = Prediction_matrix.append(pd.Series([ movieId, predicted_rating], index=Prediction_matrix_columns), ignore_index=True)
# Out:
#   File "<ipython-input-130-fe6fcb3327f4>", line 4
#     Prediction_matrix=pd.DataFrame(columns= Prediction_matrix_columns)
#     ^
# IndentationError: unexpected indent

# %%
if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
       mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
   else:
       mean_rating = 2.5

   # calculate the rating of the given movie by the given user
   user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
   user_distinct_movies = np.unique(user_other_ratings['movieId'])
   sum_weighted_other_ratings = 0
   sum_weghts = 0
   for movie_j in user_distinct_movies:
       if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
           rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
       else:
           rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
       w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
       if w_movie_1_2.shape[0] > 0:
           user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
           sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
           sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])

   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
   if sum_weghts == 0:
       predicted_rating = mean_rating
   # sum_weights is bigger than 0
   else:
       predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts

    return predicted_rating
# Out:
#   File "<tokenize>", line 4
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def predict(userId, movieId, w_matrix, adjusted_ratings, rating_mean):
   # fix missing mean rating which was caused by no ratings for the given movie
   
    # mean_rating exists for movieId
   if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
       mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
   else:
       mean_rating = 2.5

   # calculate the rating of the given movie by the given user
   user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
   user_distinct_movies = np.unique(user_other_ratings['movieId'])
   sum_weighted_other_ratings = 0
   sum_weghts = 0
   for movie_j in user_distinct_movies:
       if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
           rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
       else:
           rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
       w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
       if w_movie_1_2.shape[0] > 0:
           user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
           sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
           sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])

   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
   if sum_weghts == 0:
       predicted_rating = mean_rating
   # sum_weights is bigger than 0
   else:
       predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts

   return predicted_rating

# %%
def predict(userId, w_matrix, adjusted_ratings, rating_mean):
   # fix missing mean rating which was caused by no ratings for the given movie
  Prediction_matrix_columns = ['movieID', 'Prediction']
  Prediction_matrix=pd.DataFrame(columns= Prediction_matrix_columns)
    # mean_rating exists for movieId
  for movieId in list(distinct_movies['MovieId']):
    # mean_rating exists for movieId
      if rating_mean[rating_mean['movieId'] == movieId].shape[0] > 0:
          mean_rating = rating_mean[rating_mean['movieId'] == movieId]['rating_mean'].iloc[0]
   # mean_rating does not exist for movieId(which may be caused by no ratings for the movie)
      else:
          mean_rating = 2.5

   # calculate the rating of the given movie by the given user
      user_other_ratings = adjusted_ratings[adjusted_ratings['userId'] == userId]
      user_distinct_movies = np.unique(user_other_ratings['movieId'])
      sum_weighted_other_ratings = 0
      sum_weghts = 0
      for movie_j in user_distinct_movies:
          if rating_mean[rating_mean['movieId'] == movie_j].shape[0] > 0:
             rating_mean_j = rating_mean[rating_mean['movieId'] == movie_j]['rating_mean'].iloc[0]
          else:
             rating_mean_j = 2.5
       # only calculate the weighted values when the weight between movie_1 and movie_2 exists in weight matrix
          w_movie_1_2 = w_matrix[(w_matrix['movie_1'] == movieId) & (w_matrix['movie_2'] == movie_j)]
          if w_movie_1_2.shape[0] > 0:
             user_rating_j = user_other_ratings[user_other_ratings['movieId']==movie_j]
             sum_weighted_other_ratings += (user_rating_j['rating'].iloc[0] - rating_mean_j) * w_movie_1_2['weight'].iloc[0]
             sum_weghts += np.abs(w_movie_1_2['weight'].iloc[0])

   # if sum_weights is 0 (which may be because of no ratings from new users), use the mean ratings
      if sum_weghts == 0:
         predicted_rating = mean_rating
   # sum_weights is bigger than 0
      else:
         predicted_rating = mean_rating + sum_weighted_other_ratings/sum_weghts
      
      Prediction_matrix = Prediction_matrix.append(pd.Series([ movieId, predicted_rating], index=Prediction_matrix_columns), ignore_index=True)      
      
  return Prediction_matrix

# %%
prediction_matrix=predict(6, weight_matrix, adjusted_ratings, rating_mean)

# %%
prediction_matrix.head()
# Out:
#    movieID  Prediction
# 0      1.0    4.768579
# 1      2.0    4.120322
# 2      3.0    4.249836
# 3      4.0    3.791170
# 4      5.0    3.950777

# %%
prediction_matrix=prediction_matrix.sort_values("Prediction",ascending=False)

# %%
prediction_matrix.head()
# Out:
#     movieID  Prediction
# 49     50.0    5.152960
# 16     17.0    4.983673
# 27     28.0    4.950932
# 40     41.0    4.949163
# 5       6.0    4.911670
